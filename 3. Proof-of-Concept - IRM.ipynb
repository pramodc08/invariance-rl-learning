# %%
import math
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import deque, namedtuple

# %%
SEED = 42

def set_seed(seed=SEED):
    # NumPy
    np.random.seed(seed)
    # PyTorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(SEED)

# %%
from lunar_lander import LunarLander
from wrapper import NonCausalInternalLunarLanderObsWrapper
base_env = LunarLander(enable_wind=False)
env_1 = NonCausalInternalLunarLanderObsWrapper(base_env, scale=1.0, noise_level=0.01)
env_2 = NonCausalInternalLunarLanderObsWrapper(base_env, scale=-2.0, noise_level=0.01)
env_3 = NonCausalInternalLunarLanderObsWrapper(base_env, scale=3.0, noise_level=0.01)
envs = [env_1, env_2, env_3]
for i_env in envs:
    i_env.reset(seed=SEED)
test_env_1 = NonCausalInternalLunarLanderObsWrapper(base_env, scale=0.0, noise_level=0.0)  # No noise
test_env_2 = NonCausalInternalLunarLanderObsWrapper(base_env, scale=-1.0, noise_level=0.0) # Within range but not trained
test_env_3 = NonCausalInternalLunarLanderObsWrapper(base_env, scale=5.0, noise_level=0.0)  # Out of range
test_envs = [test_env_1, test_env_2, test_env_3]
for i_env in test_envs:
    i_env.reset(seed=SEED)

# %%
state_shape = envs[0].observation_space.shape[0]
action_shape = envs[0].action_space.n

# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Hyperparameters
BUFFER_SIZE = 100000  # Replay memory size
BATCH_SIZE = 64       # Minibatch size
GAMMA = 0.99          # Discount factor
TAU = 1e-3            # Soft update of target parameters
LR = 5e-4             # Learning rate
UPDATE_EVERY = 5      # How often to update the network
N_EPOCHS = 5      
# Training parameters
n_episodes = 3000
max_t = 1000
eps_start = 1.0
eps_end = 0.01
eps_decay = 0.995
recurrent = False
# Out:
# Using device: cuda

# %%
from agent import Agent

agent = Agent(state_size=state_shape, action_size=action_shape, device=device,
        recurrent=recurrent, lr=LR, buffer_size=BUFFER_SIZE, batch_size=BATCH_SIZE, gamma=GAMMA,
        tau=TAU, update_every=UPDATE_EVERY, n_epochs=N_EPOCHS)
# Out:
# Initializing Vanilla DQN Agent (MLP)...
# DeepQNetwork(
#   (fc1): Linear(in_features=19, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
n_envs = len(envs)
n_test_envs = len(test_envs)

train_returns = [[] for _ in range(n_envs)]
scores_window = [deque(maxlen=100) for _ in range(n_envs)]
train_mean_returns = [[] for _ in range(n_envs)]  # avg value during training rollout

env_eval_returns  = [[] for _ in range(n_envs)]
test_eval_returns = [[] for _ in range(n_test_envs)]

eps = eps_start
print("Training started...")
for i_episode in range(1, n_episodes + 1):
    states = []
    hiddens = []
    dones = [False] * n_envs
    episode_scores = np.zeros(n_envs, dtype=np.float32)
    for env in envs:
        s, _ = env.reset()
        states.append(s)
        hiddens.append(agent.qnetwork_local.init_hidden(1))
    # --- rollout ---
    for t in range(max_t):
        for i, env in enumerate(envs):
            if dones[i]:
                continue
            action, next_hidden = agent.act(states[i], eps, hiddens[i])
            next_state, reward, done, truncated, _ = env.step(action)
            terminal = done or truncated
            agent.step(
                states[i], action, reward,
                next_state, terminal,
                hiddens[i], next_hidden
            )
            states[i] = next_state
            hiddens[i] = next_hidden
            episode_scores[i] += reward
            dones[i] = terminal
        if all(dones):
            break

    for i in range(n_envs):
        ep_ret = float(episode_scores[i])
        train_returns[i].append(ep_ret)
        scores_window[i].append(ep_ret)
        train_mean_returns[i].append(np.mean(scores_window[i]))

    eps = max(eps_end, eps_decay * eps)
    env_stats = " | ".join(
        f"Env{i}: {np.mean(scores_window[i]):.2f}"
        for i in range(n_envs)
    )
    print(
        f"\rEpisode {i_episode}"
        f"\t{env_stats}"
        f"\tEps: {eps:.3f}",
        end=""
    )

    if i_episode % 10 == 0:
        for i, env in enumerate(envs):
            eval_list = []
            for _ in range(5):
                state, _ = env.reset()
                hidden = agent.qnetwork_local.init_hidden(1)
                total = 0.0

                for t in range(max_t):
                    action, next_hidden = agent.act(state, eps=0.0, hidden=hidden)
                    next_state, reward, done, truncated, _ = env.step(action)
                    state = next_state
                    hidden = next_hidden
                    total += reward
                    if done or truncated:
                        break
                eval_list.append(total)
            env_eval_returns[i].append(float(np.mean(eval_list)))
             
        for i, env in enumerate(test_envs):
            eval_list = []
            for _ in range(5):
                state, _ = env.reset()
                hidden = agent.qnetwork_local.init_hidden(1)
                total = 0.0
                for t in range(max_t):
                    action, next_hidden = agent.act(
                        state, eps=0.0, hidden=hidden
                    )
                    next_state, reward, done, truncated, _ = env.step(action)
                    state = next_state
                    hidden = next_hidden
                    total += reward
                    if done or truncated:
                        break
                eval_list.append(total)
            test_eval_returns[i].append(np.mean(eval_list))
    # --- clean newline every 100 eps ---
    if i_episode % 100 == 0:
        print("\n" + "-" * 90)
        print(f"Episode {i_episode}")
        for i in range(n_envs):
            line = f"  Env{i}: Train Avg(100)={np.mean(scores_window[i]):.2f}"
            if env_eval_returns[i]:
                line += f" | Eval={env_eval_returns[i][-1]:.2f}"
            print(line)

        for i in range(n_test_envs):
            print(f"  TestEnv{i}: Test Eval={test_eval_returns[i][-1]:.2f}")
# Out:
# Training started...
# Episode 100	Env0: -111.94 | Env1: -115.50 | Env2: -112.06	Eps: 0.606
# ------------------------------------------------------------------------------------------
# Episode 100
#   Env0: Train Avg(100)=-111.94 | Eval=-260.25
#   Env1: Train Avg(100)=-115.50 | Eval=-256.50
#   Env2: Train Avg(100)=-112.06 | Eval=-733.53
#   TestEnv0: Test Eval=-177.72
#   TestEnv1: Test Eval=-140.40
#   TestEnv2: Test Eval=-443.45
# Episode 109	Env0: -114.76 | Env1: -112.85 | Env2: -110.72	Eps: 0.579
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 30
#      28 next_state, reward, done, truncated, _ = env.step(action)
#      29 terminal = done or truncated
# ---> 30 agent.step(
#      31     states[i], action, reward,
#      32     next_state, terminal,
#      33     hiddens[i], next_hidden
#      34 )
#      35 states[i] = next_state
#      36 hiddens[i] = next_hidden
#
# File ~/pramod_private/invariance-rl-learning/agent.py:59, in Agent.step(self, state, action, reward, next_state, done, hidden, next_hidden)
#      57 if self.t_step == 0:
#      58     if len(self.memory) > self.batch_size:
# ---> 59         experiences = self.memory.sample()
#      60         self.learn(experiences)
#
# File ~/pramod_private/invariance-rl-learning/buffers.py:25, in ReplayBuffer.sample(self)
#      22 experiences = [self.memory[i] for i in indices]
#      24 states = torch.from_numpy(np.vstack([e.state for e in experiences if e is not None])).float().to(self.device)
# ---> 25 actions = torch.from_numpy(np.vstack([e.action for e in experiences if e is not None])).long().to(self.device)
#      26 rewards = torch.from_numpy(np.vstack([e.reward for e in experiences if e is not None])).float().to(self.device)
#      27 next_states = torch.from_numpy(np.vstack([e.next_state for e in experiences if e is not None])).float().to(self.device)
#
# File ~/pramod_private/invariance-rl-learning/venv/lib/python3.10/site-packages/numpy/_core/shape_base.py:292, in vstack(tup, dtype, casting)
#     290 if not isinstance(arrs, tuple):
#     291     arrs = (arrs,)
# --> 292 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# KeyboardInterrupt:

# %%
n_envs = len(envs)
n_test_envs = len(test_envs)

eval_every = 10  # you evaluate every 10 episodes

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12), sharex=True)

# --- Training scores ---
for i in range(n_envs):
    x = np.arange(1, len(train_mean_returns[i]) + 1)
    ax1.plot(x, train_mean_returns[i], label=f'Env-{i}')
    
ax1.set_ylabel('Score')
ax1.set_xlabel('Episode #')
ax1.set_title('Training Returns (Averaged)')
ax1.grid(True)
ax1.legend(ncol=1)

for i in range(n_envs):
    eval_x = np.arange(1, len(env_eval_returns[i]) + 1) * eval_every
    ax2.plot(
        eval_x,
        env_eval_returns[i],
        marker='o',
        linestyle='-',
        label=f'Env-{i}'
    )

ax2.set_ylabel('Score')
ax2.set_xlabel('Episode #')
ax2.set_title(f'Evaluation on training envs (eps=0, every {eval_every} episodes)')
ax2.grid(True)
ax2.legend(ncol=1)

for i in range(n_test_envs):
    eval_test_x = np.arange(1, len(test_eval_returns[i]) + 1) * eval_every
    ax3.plot(
        eval_test_x,
        test_eval_returns[i],
        marker='o',
        linestyle='-',
        label=f'Test-Env-{i}'
    )

ax3.set_ylabel('Score')
ax3.set_xlabel('Episode #')
ax3.set_title(f'Evaluation on test envs (eps=0, every {eval_every} episodes)')
ax3.grid(True)
ax3.legend(ncol=1)

plt.tight_layout()
plt.show()

# %%
from buffers import ReplayBuffer, HiddenStateReplayBuffer
from agent import Agent

buffers = [
    HiddenStateReplayBuffer(
        action_size=action_shape,
        buffer_size=BUFFER_SIZE,
        batch_size=BATCH_SIZE,
        device=device
    ) if recurrent else ReplayBuffer(
        action_size=action_shape,
        buffer_size=BUFFER_SIZE,
        batch_size=BATCH_SIZE,
        device=device
    )
    for _ in envs
]
group_weights = torch.tensor([0.5 for i in envs]) # Start with equal weighting for env_1 and env_2

irm_agent = Agent(state_size=state_shape, action_size=action_shape, device=device,
        recurrent=recurrent, lr=LR, buffer_size=BUFFER_SIZE, batch_size=BATCH_SIZE, gamma=GAMMA,
        tau=TAU, update_every=UPDATE_EVERY, n_epochs=N_EPOCHS)
# Out:
# Initializing Vanilla DQN Agent (MLP)...
# DeepQNetwork(
#   (fc1): Linear(in_features=19, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=4, bias=True)
# )

# %%
def learn(agent, experiences, scale=1.0):
    """Update value parameters using given batch of experience tuples."""
    if agent.recurrent:
        states, actions, rewards, next_states, dones, hidden, next_hidden = experiences
    else:
        states, actions, rewards, next_states, dones = experiences

    # ------------------- Compute Target Q ------------------- #
    with torch.no_grad():
        if agent.recurrent:
            # Double DQN for LSTM:
            # 1. Select best action using Local Net + Next Hidden State
            local_next_out, _ = agent.qnetwork_local(next_states, next_hidden)
            best_actions = local_next_out.argmax(1).unsqueeze(1)
            
            # 2. Evaluate using Target Net + Next Hidden State
            target_next_out, _ = agent.qnetwork_target(next_states, next_hidden)
            Q_targets_next = target_next_out.gather(1, best_actions)
        else:
            # Double DQN for MLP:
            best_actions = agent.qnetwork_local(next_states).argmax(1).unsqueeze(1)
            Q_targets_next = agent.qnetwork_target(next_states).gather(1, best_actions)
        Q_targets = rewards + (agent.gamma * Q_targets_next * (1 - dones))


    if agent.recurrent:
        # Forward pass with the STORED hidden state from the buffer
        current_out, _ = agent.qnetwork_local(states, hidden)
        Q_expected = current_out.gather(1, actions)
    else:
        Q_expected = agent.qnetwork_local(states).gather(1, actions)

    Q_expected = Q_expected * scale
    # Compute loss
    loss = F.smooth_l1_loss(Q_expected, Q_targets)
    return loss

def irm_penalty(losses_per_env, scale):
    # losses_per_env: list of scalars, one per env
    grads = [torch.autograd.grad(l, scale, create_graph=True)[0] for l in losses_per_env]
    return sum((g**2).sum() for g in grads)
# Should be mulitply not sum in inner loop

# %%
n_envs = len(envs)
n_test_envs = len(test_envs)

train_returns = [[] for _ in range(n_envs)]
scores_window = [deque(maxlen=100) for _ in range(n_envs)]
train_mean_returns = [[] for _ in range(n_envs)]  # avg value during training rollout

env_eval_returns  = [[] for _ in range(n_envs)]
test_eval_returns = [[] for _ in range(n_test_envs)]

eps = eps_start
t_step = 0
print("Training started...")
for i_episode in range(1, n_episodes + 1):
    states = []
    hiddens = []
    dones = [False] * n_envs
    episode_scores = np.zeros(n_envs, dtype=np.float32)
    for env in envs:
        s, _ = env.reset()
        states.append(s)
        hiddens.append(irm_agent.qnetwork_local.init_hidden(1))
    # --- rollout ---
    for t in range(max_t):
        for i, env in enumerate(envs):
            if dones[i]:
                continue
            action, next_hidden = irm_agent.act(states[i], eps, hiddens[i])
            next_state, reward, done, truncated, _ = env.step(action)
            terminal = done or truncated

            if recurrent:
                buffers[i].add(states[i], action, reward, next_state, terminal, hiddens[i], next_hidden)
            else:
                buffers[i].add(states[i], action, reward, next_state, terminal)

            states[i] = next_state
            hiddens[i] = next_hidden
            episode_scores[i] += reward
            dones[i] = terminal
        
        # Train step
        t_step += 1
        if all([len(i) > irm_agent.batch_size for i in buffers]):
            t_step = (t_step + 1) % irm_agent.update_every
            if t_step == 0:
                lambda_irm=1.0
                scale = torch.tensor(1.0, device=agent.device, requires_grad=True)
                
                losses = []
                for i, env in enumerate(envs):
                    experience = buffers[i].sample()
                    loss_i = learn(irm_agent, experience, scale)
                    losses.append(loss_i)

                erm = torch.stack(losses).mean()
                penalty = irm_penalty(losses, scale)
                loss = erm + lambda_irm * penalty
                irm_agent.optimizer.zero_grad(set_to_none=True)
                loss.backward()
                torch.nn.utils.clip_grad_norm_(irm_agent.qnetwork_local.parameters(), 1.0)
                irm_agent.optimizer.step()
                
                irm_agent.soft_update(irm_agent.qnetwork_local, irm_agent.qnetwork_target, irm_agent.tau)

        if all(dones):
            break
        
    for i in range(n_envs):
        ep_ret = float(episode_scores[i])
        train_returns[i].append(ep_ret)
        scores_window[i].append(ep_ret)
        train_mean_returns[i].append(np.mean(scores_window[i]))

    eps = max(eps_end, eps_decay * eps)
    env_stats = " | ".join(
        f"Env{i}: {np.mean(scores_window[i]):.2f}"
        for i in range(n_envs)
    )
    print(
        f"\rEpisode {i_episode}"
        f"\t{env_stats}"
        f"\tEps: {eps:.3f}",
        end=""
    )

    if i_episode % 10 == 0:
        for i, env in enumerate(envs):
            eval_list = []
            for _ in range(5):
                state, _ = env.reset()
                hidden = irm_agent.qnetwork_local.init_hidden(1)
                total = 0.0

                for t in range(max_t):
                    action, next_hidden = irm_agent.act(state, eps=0.0, hidden=hidden)
                    next_state, reward, done, truncated, _ = env.step(action)
                    state = next_state
                    hidden = next_hidden
                    total += reward
                    if done or truncated:
                        break
                eval_list.append(total)
            env_eval_returns[i].append(float(np.mean(eval_list)))
            
        for i, env in enumerate(test_envs):
            eval_list = []
            for _ in range(5):
                state, _ = env.reset()
                hidden = irm_agent.qnetwork_local.init_hidden(1)
                total = 0
                for t in range(max_t):
                    action, next_hidden = irm_agent.act(
                        state, eps=0.0, hidden=hidden
                    )
                    next_state, reward, done, truncated, _ = env.step(action)
                    state = next_state
                    hidden = next_hidden
                    total += reward
                    if done or truncated:
                        break
                eval_list.append(total)
            test_eval_returns[i].append(np.mean(eval_list))
    if i_episode % 100 == 0:
        print("\n" + "-" * 90)
        print(f"Episode {i_episode}")
        for i in range(n_envs):
            line = f"  Env{i}: Train Avg(100)={np.mean(scores_window[i]):.2f}"
            if env_eval_returns[i]:
                line += f" | Eval={env_eval_returns[i][-1]:.2f}"
            print(line)

        for i in range(n_test_envs):
            print(f"  TestEnv{i}: Test Eval={test_eval_returns[i][-1]:.2f}")
# Out:
# Training started...
# Episode 100	Env0: -134.05 | Env1: -136.53 | Env2: -131.01	Eps: 0.606
# ------------------------------------------------------------------------------------------
# Episode 100
#   Env0: Train Avg(100)=-134.05 | Eval=-285.54
#   Env1: Train Avg(100)=-136.53 | Eval=-466.79
#   Env2: Train Avg(100)=-131.01 | Eval=-187.80
#   TestEnv0: Test Eval=-258.50
#   TestEnv1: Test Eval=-319.43
#   TestEnv2: Test Eval=-197.37
# Episode 200	Env0: -109.93 | Env1: -119.29 | Env2: -124.31	Eps: 0.367
# ------------------------------------------------------------------------------------------
# Episode 200
#   Env0: Train Avg(100)=-109.93 | Eval=-337.19
#   Env1: Train Avg(100)=-119.29 | Eval=-330.97
#   Env2: Train Avg(100)=-124.31 | Eval=-615.58
#   TestEnv0: Test Eval=-200.97
#   TestEnv1: Test Eval=-175.68
#   TestEnv2: Test Eval=-677.10
# Episode 300	Env0: -111.69 | Env1: -118.35 | Env2: -131.94	Eps: 0.222
# ------------------------------------------------------------------------------------------
# Episode 300
#   Env0: Train Avg(100)=-111.69 | Eval=-379.41
#   Env1: Train Avg(100)=-118.35 | Eval=-602.86
#   Env2: Train Avg(100)=-131.94 | Eval=-41.13
#   TestEnv0: Test Eval=-380.76
#   TestEnv1: Test Eval=-348.28
#   TestEnv2: Test Eval=-255.66
# Episode 400	Env0: -149.27 | Env1: -158.04 | Env2: -172.70	Eps: 0.135
# ------------------------------------------------------------------------------------------
# Episode 400
#   Env0: Train Avg(100)=-149.27 | Eval=-728.69
#   Env1: Train Avg(100)=-158.04 | Eval=-286.44
#   Env2: Train Avg(100)=-172.70 | Eval=-425.90
#   TestEnv0: Test Eval=-628.80
#   TestEnv1: Test Eval=-585.44
#   TestEnv2: Test Eval=-386.58
# Episode 500	Env0: -223.26 | Env1: -230.45 | Env2: -227.93	Eps: 0.082
# ------------------------------------------------------------------------------------------
# Episode 500
#   Env0: Train Avg(100)=-223.26 | Eval=-685.81
#   Env1: Train Avg(100)=-230.45 | Eval=-360.53
#   Env2: Train Avg(100)=-227.93 | Eval=-1273.23
#   TestEnv0: Test Eval=-510.67
#   TestEnv1: Test Eval=-680.33
#   TestEnv2: Test Eval=-806.76
# Episode 600	Env0: -249.30 | Env1: -256.95 | Env2: -255.93	Eps: 0.049
# ------------------------------------------------------------------------------------------
# Episode 600
#   Env0: Train Avg(100)=-249.30 | Eval=-775.10
#   Env1: Train Avg(100)=-256.95 | Eval=-524.83
#   Env2: Train Avg(100)=-255.93 | Eval=-656.16
#   TestEnv0: Test Eval=-611.47
#   TestEnv1: Test Eval=-706.09
#   TestEnv2: Test Eval=-620.14
# Episode 642	Env0: -247.09 | Env1: -258.39 | Env2: -256.08	Eps: 0.040
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 28
#      26 if dones[i]:
#      27     continue
# ---> 28 action, next_hidden = irm_agent.act(states[i], eps, hiddens[i])
#      29 next_state, reward, done, truncated, _ = env.step(action)
#      30 terminal = done or truncated
#
# File ~/pramod_private/invariance-rl-learning/agent.py:75, in Agent.act(self, state, eps, hidden)
#      73         action_values, new_hidden = self.qnetwork_local(state, hidden)
#      74     else:
# ---> 75         action_values = self.qnetwork_local(state)
#      76         new_hidden = None
#      78 self.qnetwork_local.train()
#
# File ~/pramod_private/invariance-rl-learning/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/pramod_private/invariance-rl-learning/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/pramod_private/invariance-rl-learning/model.py:45, in DeepQNetwork.forward(self, state)
#      44 def forward(self, state):
# ---> 45     x = F.relu(self.fc1(state))
#      46     x = F.relu(self.fc2(x))
#      47     actions = self.fc3(x)
#
# File ~/pramod_private/invariance-rl-learning/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/pramod_private/invariance-rl-learning/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/pramod_private/invariance-rl-learning/venv/lib/python3.10/site-packages/torch/nn/modules/linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
n_envs = len(envs)
n_test_envs = len(test_envs)

eval_every = 10  # you evaluate every 10 episodes

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(12, 12), sharex=True)

# --- Training scores ---
for i in range(n_envs):
    x = np.arange(1, len(train_mean_returns[i]) + 1)
    ax1.plot(x, train_mean_returns[i], label=f'Env-{i}')
    
ax1.set_ylabel('Score')
ax1.set_xlabel('Episode #')
ax1.set_title('Training Returns (Averaged)')
ax1.grid(True)
ax1.legend(ncol=1)

for i in range(n_envs):
    eval_x = np.arange(1, len(env_eval_returns[i]) + 1) * eval_every
    ax2.plot(
        eval_x,
        env_eval_returns[i],
        marker='o',
        linestyle='-',
        label=f'Env-{i}'
    )

ax2.set_ylabel('Score')
ax2.set_xlabel('Episode #')
ax2.set_title(f'Evaluation on training envs (eps=0, every {eval_every} episodes)')
ax2.grid(True)
ax2.legend(ncol=1)

for i in range(n_test_envs):
    eval_test_x = np.arange(1, len(test_eval_returns[i]) + 1) * eval_every
    ax3.plot(
        eval_test_x,
        test_eval_returns[i],
        marker='o',
        linestyle='-',
        label=f'Test-Env-{i}'
    )

ax3.set_ylabel('Score')
ax3.set_xlabel('Episode #')
ax3.set_title(f'Evaluation on test envs (eps=0, every {eval_every} episodes)')
ax3.grid(True)
ax3.legend(ncol=1)

plt.tight_layout()
plt.show()

# %%
# penalty_multiplier = epoch ** 1.6  (Epoch: [1, 100])
 # dummy_w = torch.nn.Parameter(torch.Tensor([1.0])).to(device)
